# %% [markdown]
# # Now just using DF directly
# ## no longer need to parse separately into lists etc.  all done internally
# ## TO Do the dump load and initialize the DB, need to make sure correct order pf tables is loaded first those with no dependencies and then increasingly so.
# ## now only erroring on original 3 .txt noted by Ian Gorton in original commnication
# - - 1. Conf
# - - 2. Pub , Keys, Authors, Affiliations (use sets to create unique ones but may change to all .unique)
# - - 3. Composites (Many to Many)
# - - 4. Paper/abstracts

# %%
import sqlite3
import pandas as pd

# %%
import sqlcommands as cmd
cmd = reload(cmd)
# Out:
# (1548, 7)
# (1548, 7)

# %%
df = cmd.createTOTALTable()
df.iloc[50:60]
# Out:
# /Users/aileennovero1/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:1160: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   chunksize=chunksize, dtype=dtype)
#                                              Abstract  \
# 50  The past 20 years has seen significant investm...
# 51  Nowadays, Wireless Sensor Networks  WSN  are a...
# 52  Automated services help enterprises create new...
# 53  The term co evolution describes the symbiotic ...
# 54  Software architecture views represent the basi...
# 55  Currently, most software systems have a dynami...
# 56  We propose a pattern based software developmen...
# 57  Most of the research in the area of multimodal...
# 58  The vast diversity of implementation and suppo...
# 59                              No abstract available
#
#                                    Author affiliation  \
# 50  IBM Software Group, Raleigh, NC, United States...
# 51  Divisi n de Sistemas e Ingenier a Electr nica ...
# 52  INFOLAB, Tilburg University, Dept  of Informat...
# 53  University of St Andrews, St Andrews, KY16 9SX...
# 54  Department of Information Systems and Computat...
# 55  Department of Information Systems and Computat...
# 56  Department of Computational and Cognitive Scie...
# 57  Department of Computer Science, Technische Uni...
# 58  Computer Languages and Systems II Department, ...
# 59                                               None
#
#                                               Authors  Conf  \
# 50  ['Brown, Alan W', '', '', ' McDermid, John A',...  ECSA
# 51  ['Losilla, Fernando', '', '', 'Vicente Chicote...  ECSA
# 52                  ['Papazoglou, Michael P', '', '']  ECSA
# 53  ['Morrison, Ron', '', '', 'Balasubramaniam, Dh...  ECSA
# 54  ['Cordero, Rogelio Limon', '', '', 'Salavert, ...  ECSA
# 55  ['Costa, Crist bal', '', '', 'Ali, Nour', '', ...  ECSA
# 56  ['C t , Isabelle', '', '', 'Heisel, Marina', '...  ECSA
# 57  ['Pereira, Alessandro Costa', ' ,', '', ' Hart...  ECSA
# 58  ['L pez Sanz, Marcos', '', '', 'Acu a, C sar J...  ECSA
# 59  ['Dauvin, Jean Claude', ' Romana, Louis Alexan...  ECSA
#
#                                                 Title  \
# 50       The art and science of software architecture
# 51  Wireless sensor network application developmen...
# 52                                What s in a service
# 53  An active architecture approach to dynamic sys...
# 54  Analyzing styles of the modular software archi...
# 55  Dynamic reconfiguration of software architectu...
# 56  Pattern based evolution of software architectures
# 57  A distributed staged architecture for multimod...
# 58  UML profile for the platform independent model...
# 59                             Hydrobiologia  Preface
#
#                                                 terms  year
# 50  ['Failure analysis', 'Systems engineering', 'O...  2007
# 51  ['Mathematical models', 'Software architecture...  2007
# 52  ['Condition monitoring', 'Electronic commerce'...  2007
# 53  ['Dynamical systems', 'Grid computing', 'Senso...  2007
# 54  ['Computer aided design', 'Requirements engine...  2007
# 55  ['Computer aided design', 'Object oriented pro...  2007
# 56  ['Pattern recognition', 'Requirements engineer...  2007
# 57  ['Computer programming languages', 'Distribute...  2007
# 58  ['Computer simulation', 'Computer software por...  2007
# 59                                              [nan]  2007

# %%
#don't need 
#df1 = cmd.getPatentDataFrame(hdffile='../DataBaseParsing/DFstore4.h5')

# %%
df.iloc[0]['Author affiliation']
# Out:
# u'DISP, Univ  of Rome, Rome, Italy'

# %% [markdown]
# # Create the Conf Table

# %%
confDF = cmd.createConfTable(df)
# Out:
# Opened test.db database successfully
# Created DataFrame
# Records created successfully

# %%
confDF
# Out:
#    confID confName
# 0       1     ECSA
# 1       2     QoSA
# 2       3    WICSA

# %% [markdown]
# # Create publications Table
# ## Now can parse all the orginal .txt with exception of the same 3  Ian gorton noted were errant

# %%
pubDF = cmd.createPublicationsTable(df)
# Out:
# Opened Abstracts_DB.db database successfully
# table dropped
# Created PUBLICATIONS table
# Created DataFrame
# Records created successfully

# %%
pubDF
# Out:
#     pubID  year confName
# 0       1  2007     ECSA
# 1       2  2008     ECSA
# 2       3  2009     ECSA
# 3       4  2010     ECSA
# 4       5  2011     ECSA
# 5       6  2012     ECSA
# 6       7  2013     ECSA
# 7       8  2014     ECSA
# 8       9  2005     QoSA
# 9      10  2006     QoSA
# 10     11  2007     QoSA
# 11     12  2008     QoSA
# 12     13  2009     QoSA
# 13     14  2010     QoSA
# 14     15  2011     QoSA
# 15     16  2012     QoSA
# 16     17  2013     QoSA
# 17     18  2014     QoSA
# 18     19  2004    WICSA
# 19     20  2005    WICSA
# 20     21  2007    WICSA
# 21     22  2008    WICSA
# 22     23  2009    WICSA
# 23     24  2011    WICSA
# 24     25  2012    WICSA
# 25     26  2014    WICSA

# %% [markdown]
# # Create Keys Table

# %% [markdown]
# ## There are errors here and I have spent way to ong trying to figure if out.
# ## Somewhere the abstracts are being split into the terms.

# %%
keys = cmd.createKEYSTable(df)
# Out:
# Opened Abstracts_DB.db database successfully
#               keyword
# 0     Loose couplings
# 1   aspectual concept
# 2       Discrete time
# 3  Polyacrylonitriles
# 4     Tacit knowledge
# Created DataFrame
# Records created successfully

# %%
print len(keys)
print len(keys.keyword.unique())
keys.iloc[50:100]
# Out:
# 8399
# 8399
#     keyID                                            keyword
# 50     51                            Bifunctional mechanisms
# 51     52                                 Traceability model
# 52     53                            Architectural structure
# 53     54                              Local decision-making
# 54     55                  ontology-driven pattern selection
# 55     56                              Service-based systems
# 56     57                                          PIM level
# 57     58                                 Web implementation
# 58     59  Poor long-term performance and durability comb...
# 59     60                                   ruthenium alloys
# 60     61                           concrete component model
# 61     62                                    Water pollution
# 62     63                                          assurance
# 63     64                Proton exchange membrane fuel cells
# 64     65                   X ray photoemission spectroscopy
# 65     66                           Temperature Measurements
# 66     67                   ubiquitous computing environment
# 67     68                                 Methanol Oxidation
# 68     69                     p-calculus based communication
# 69     70                              Classification scheme
# 70     71                                 Design flexibility
# 71     72                           Exploratory case studies
# 72     73                                    Virtual reality
# 73     74                                    Self-adaptivity
# 74     75                      scenario-driven risk analysis
# 75     76                                      Data elements
# 76     77                           multimedia communication
# 77     78                         Atmospheric thermodynamics
# 78     79                                     model checking
# 79     80                         decentralized architecture
# 80     81                                    Modelling tools
# 81     82                                      cost analysis
# 82     83                                  failure diagnosis
# 83     84                                  embedded software
# 84     85                                Adaptation services
# 85     86                                       User context
# 86     87                            parameterised contracts
# 87     88                   software reconfiguration pattern
# 88     89                      resource-aware infrastructure
# 89     90                             public domain software
# 90     91                               Adaptation framework
# 91     92                                           Supports
# 92     93                      architecture-centric approach
# 93     94                              program understanding
# 94     95                                       Inner region
# 95     96                             fault tolerant systems
# 96     97                                  Processing Agents
# 97     98                               capturing activities
# 98     99                        and imposed on another view
# 99    100                                Information Science

# %% [markdown]
# # Authors
# ## I don't know how to parse them better!  Each text file seems to look at them differently and no idea what to do

# %%
authorsset, sqlAUDF = cmd.createAUTHORSTable(df)
# Out:
# Opened Abstracts_DB.db database successfully
# Author set created
# Records created successfully

# %%
print len(authorsset) #first is empty!
authorsset[0:3]
# Out:
# 2912
# [u'', u'Kolb  Ronny', u'Von Massow  Robert']

# %%
print len(sqlAUDF.AuthorName.drop_duplicates())  #<<--- double check!  will keep one 'empty ' ' becuase of set)
sqlAUDF.head()
# Out:
# 2911
#    authorID          AuthorName
# 0         1         Kolb  Ronny
# 1         2  Von Massow  Robert
# 2         3       Smiley  Karen
# 3         4        Prakash  Jai
# 4         5       Zhang  Hongye

# %% [markdown]
# # Affiliation Table
# ## simple no extra parsing do to differences between entries

# %%
affilDF= cmd.createAFFILIATIONTable(df)
# Out:
# Opened test3.db database successfully
# Created DataFrame
# Records created successfully

# %%
affilDF
# Out:
#       affilID                                        affiliation
# 0           1                   DISP, Univ  of Rome, Rome, Italy
# 1           2                        LSTS   ENIT, Tunis, Tunisia
# 2           3  INRIA, Univ  des Sci  et Technol  de Lille, Vi...
# 3           4  Sch  of Comput  Sci , Univ  of Adelaide, Adela...
# 4           5    Software Group, IBM, Raleigh, NC, United States
# 5           6         Comput  Syst  Dept , UCLM, Albacete, Spain
# 6           7  Dept  of Comput  Sci , Univ  of Aarhus, Arhus,...
# 7           8  Dipt  Estadi stica, Comput  Univ  de La Laguna...
# 8           9  Comput  Sci  Dept , Pontifical Catholic Univ ,...
# 9          10  Comput  Languages   Syst  II Dept , Rey Juan C...
# 10         11  Dept  of Comput  Sci , VU Univ  Amsterdam, Ams...
# 11         12  Div  de Sist  e Ing  Electron   DSIE , Univ  P...
# 12         13  Dept  of Comput  Sci , Univ  of Leicester, Lei...
# 13         14  Dept  of Autom  Control   Syst  Eng , Univ  of...
# 14         15  Dept  of Inf  Syst    Comput , Polytech  Univ ...
# 15         16  Dept  of Inf  Syst    Comput , Tech  Univ  of ...
# 16         17  Dept  for Appl  Telematics   e Bus , Univ  of ...
# 17         18  Sch  of Comput  Sci , Carnegie Mellon Univ , P...
# 18         19  Depto  de Inf , Univ  de Valladolid, Valladoli...
# 19         20  Dept  of Math    Comput  Sci , Univ  of Gronin...
# 20         21  Dept  of Comput  Sci , Univ  of Malaga, Malaga...
# 21         22                                               None
# 22         23  Computer Science Department, PUC, Rio, Brazil ...
# 23         24  University of Sfax, Research Unit ReDCAD, B P ...
# 24         25  Department of Computer Science, University of ...
# 25         26  Department of Computer Science, VU University ...
# 26         27  Warsaw University of Technology, Institute of ...
# 27         28  LIFL, INRIA Team ADAM, Universit  des Sciences...
# 28         29  Division of Electronics Engineering and System...
# 29         30  School of Computer Science, University of Adel...
# ...       ...                                                ...
# 1086     1087  Deep SE Group, Dipartimento di Elettronica Inf...
# 1087     1088  RWTH Aachen University, Research Group Softwar...
# 1088     1089  Johannes Kepler University Linz, Linz, Austria...
# 1089     1090  Amrita Vishwa Vidyapeetham, India  2  Universi...
# 1090     1091  Christian Doppler Laboratory, MEVSS, Johannes ...
# 1091     1092                  University of Lugano, Switzerland
# 1092     1093  Department of Computer Science, Federal Univer...
# 1093     1094  VU University Amsterdam, Netherlands  2  Vienn...
# 1094     1095  University of Canterbury, Christchurch, New Ze...
# 1095     1096  Department of Information Engineering, Compute...
# 1096     1097  Lero   the Irish Software Engineering Research...
# 1097     1098  University of Groningen, Netherlands  2  ABB C...
# 1098     1099  Charles University in Prague, Faculty of Mathe...
# 1099     1100  Department of Information and Computing Scienc...
# 1100     1101  Department of Computer Science, Linnaeus Unive...
# 1101     1102  Industrial Software Systems, ABB Corporate Res...
# 1102     1103  ABB Corporate Research, M lardalen University,...
# 1103     1104  Aalto University, School of Science, Finland  ...
# 1104     1105  Clausthal University of Technology, Department...
# 1105     1106  Alten AB, Stockholm, Sweden  2  M lardalen Uni...
# 1106     1107  IT University of Copenhagen, Denmark  2  Unive...
# 1107     1108  Department of Informatics, Clausthal Universit...
# 1108     1109  Siemens AG Osterreich, Corporate Technology Vi...
# 1109     1110  Information Systems Architecture Research Grou...
# 1110     1111  SWAT Lab , DGIGL, Polytechnique Montr al, Qu b...
# 1111     1112  Federal University of Bahia, Av  Adhemar de Ba...
# 1112     1113  University of Groningen, Nijenborgh 9, 9747 AG...
# 1113     1114  Department of Informatics, Universidad Tecnica...
# 1114     1115  Dept  of Computer Systems, University of S o P...
# 1115     1116  ABB Corporate Research Germany, Industrial Sof...
#
# [1116 rows x 2 columns]
