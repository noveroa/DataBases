# %% [markdown]
# # Now just using DF directly
# ## no longer need to parse separately into lists etc.  all done internally
# ## TO Do the dump load and initialize the DB, need to make sure correct order pf tables is loaded first those with no dependencies and then increasingly so.
# ## now only erroring on original 3 .txt noted by Ian Gorton in original commnication
# - - 1. Conf
# - - 2. Pub , Keys, Authors, Affiliations (use sets to create unique ones but may change to all .unique)
# - - 3. Composites (Many to Many)
# - - 4. Paper/abstracts

# %%
import sqlite3
import pandas as pd

# %%
import sqlcommands as cmd
cmd = reload(cmd)
# Out:
# (1061, 7)

# %%
df = cmd.createTOTALTable()
df.iloc[50:60]
# Out:
#                                              Abstract  \
# 50  Enterprise Architecture  EA  has undergone man...
# 51  In domains, where great variability of require...
# 52  Software architecture can be represented as a ...
# 53  In this paper, we propose the application of c...
# 54  Empirical software engineering focuses on the ...
# 55  Software architecture description languages al...
# 56  When an application must evolve to cope with n...
# 57  Ageless software evolves, to meet new requirem...
# 58  The past 20 years has seen significant investm...
# 59  Many issues must be taken into account in orde...
#
#                                    Author affiliation  \
# 50  International Graduate School of Dynamic Intel...
# 51  Kaunas University of Technology, Studentu 50, ...
# 52                     University of British Columbia
# 53  Federal University of Rio Grande do Norte  UFR...
# 54                   DISP, Univ  of Rome, Rome, Italy
# 55                        LSTS   ENIT, Tunis, Tunisia
# 56  INRIA, Univ  des Sci  et Technol  de Lille, Vi...
# 57  Sch  of Comput  Sci , Univ  of Adelaide, Adela...
# 58    Software Group, IBM, Raleigh, NC, United States
# 59         Comput  Syst  Dept , UCLM, Albacete, Spain
#
#                                               Authors  Conf  \
# 50  ['Assmann, Martin', ' ,', '', ' Engels, Gregor...  ECSA
# 51  ['Damaevicius, Robertas', '', '', '', ' tuikys...  ECSA
# 52       ['Lee, Larix', '', '', 'Kruchten, Philippe']  ECSA
# 53  ['Batista, Thais', '', '', 'Gomes, Ant', ' nio...  ECSA
# 54  ['Falessi, D', '', '', ' Kruchten, P', ' Canto...  ECSA
# 55  ['Jerad, C', '', '', ' Barkaoui, K', ' Grissa ...  ECSA
# 56  ['Waignier, G', '', '', ' Le Meur, A', 'F', ''...  ECSA
# 57  ['Falkner, K', '', '', ' Balasubramaniam, D', ...  ECSA
# 58           ['Brown, A W', '', '', ' McDermid, J A']  ECSA
# 59  ['Navarro, E', '', '', ' Letelier, P', ' Jaen,...  ECSA
#
#                                                 Title  \
# 50  Transition to service oriented enterprise arch...
# 51  Domain ontology based generative component des...
# 52  Visualizing software architectural design deci...
# 53  On the interplay of aspects and dynamic reconf...
# 54  Issues in applying empirical software engineer...
# 55  Hierarchical verification in Maude of LfP soft...
# 56  FIESTA  a generic framework for integrating ne...
# 57                                 Informed evolution
# 58       The art and science of software architecture
# 59  Supporting the automatic generation of proto a...
#
#                                                 terms  year
# 50  ['Architecture', 'Information services', 'Web ...  2008
# 51  ['Digital signal processing', 'Integrated circ...  2008
# 52  ['Design', 'Software architecture', 'Software ...  2008
# 53  ['Blending', 'Dynamic models', 'Software desig...  2008
# 54  ['software architecture', 'software quality', ...  2008
# 55  ['formal verification', 'rewriting systems', '...  2008
# 56  ['formal specification', 'software architectur...  2008
# 57  ['software architecture', 'software prototypin...  2008
# 58  ['safety-critical software', 'software archite...  2008
# 59  ['software architecture', 'proto-architectures...  2008

# %%
#don't need 
#df1 = cmd.getPatentDataFrame(hdffile='../DataBaseParsing/DFstore4.h5')

# %%
df.iloc[0]['Author affiliation']
# Out:
# u'None'

# %% [markdown]
# # Create the Conf Table

# %%
confDF = cmd.createConfTable(df, db = 'Abstracts_DB2.db')
# Out:
# Opened Abstracts_DB2.db database successfully
# Created DataFrame
# Records created successfully

# %%
confDF
# Out:
#    confID confName
# 0       1     ECSA
# 1       2     QoSA
# 2       3    WICSA

# %% [markdown]
# # Create publications Table
# ## Now can parse all the orginal .txt with exception of the same 3  Ian gorton noted were errant

# %%
pubDF = cmd.createPublicationsTable(df)
# Out:
# Opened Abstracts_DB2.db database successfully
# table dropped
# Created PUBLICATIONS table
# Created DataFrame
# Records created successfully

# %%
pubDF
# Out:
#     pubID  year confName
# 0       1  2007     ECSA
# 1       2  2008     ECSA
# 2       3  2009     ECSA
# 3       4  2010     ECSA
# 4       5  2011     ECSA
# 5       6  2012     ECSA
# 6       7  2013     ECSA
# 7       8  2014     ECSA
# 8       9  2005     QoSA
# 9      10  2006     QoSA
# 10     11  2007     QoSA
# 11     12  2008     QoSA
# 12     13  2009     QoSA
# 13     14  2010     QoSA
# 14     15  2011     QoSA
# 15     16  2012     QoSA
# 16     17  2013     QoSA
# 17     18  2014     QoSA
# 18     19  2005    WICSA
# 19     20  2007    WICSA
# 20     21  2008    WICSA
# 21     22  2009    WICSA
# 22     23  2011    WICSA
# 23     24  2012    WICSA
# 24     25  2014    WICSA

# %% [markdown]
# # Create Keys Table

# %% [markdown]
# ## There are errors here and I have spent way to ong trying to figure if out.
# ## Somewhere the abstracts are being split into the terms.

# %%
keys = cmd.createKEYSTable(df)
# Out:
# Opened Abstracts_DB2.db database successfully
#            keyword
# 0  Loose couplings
# 1         Simulink
# 2             FUML
# 3    Bayesian nets
# 4            NoSQL
# Created DataFrame
# Records created successfully

# %%
print len(keys)
print len(keys.keyword.unique())
keys.iloc[50:100]
# Out:
# 5308
# 5308
#     keyID                                            keyword
# 50     51                                               Pipe
# 51     52                                  Experiment system
# 52     53                                         Life cycle
# 53     54                                Java implementation
# 54     55                                         Ecosystems
# 55     56                                       Java program
# 56     57                              Statistical inference
# 57     58                             Business opportunities
# 58     59                                    Low maintenance
# 59     60                           automatic recommendation
# 60     61                                 Traceability model
# 61     62                            Architectural structure
# 62     63                                      Data networks
# 63     64                                       Fuzzy C mean
# 64     65                              Service-based systems
# 65     66                                          PIM level
# 66     67                                   Mobile softwares
# 67     68                                 Web implementation
# 68     69                           client-driven adaptation
# 69     70                        n-way combinatorial testing
# 70     71                                 Quality prediction
# 71     72                           concrete component model
# 72     73                              Intelligent computing
# 73     74                                   Transient faults
# 74     75                                        Large sizes
# 75     76                                    impact analysis
# 76     77                                          iso 26262
# 77     78                             Worst-case performance
# 78     79                              Application protocols
# 79     80                               Diverse applications
# 80     81                            social Web applications
# 81     82                                 Design flexibility
# 82     83                                      Network edges
# 83     84                  Model-driven software development
# 84     85                               Lightweight products
# 85     86                                    Virtual reality
# 86     87  Software Architecture Reliability Analysis (SARA)
# 87     88                            Web-based request flows
# 88     89                                             Ethers
# 89     90  their practical usage in analysis and design i...
# 90     91                                   technical levels
# 91     92                                     model checking
# 92     93                                    Modelling tools
# 93     94                                      cost analysis
# 94     95                               Software interfacing
# 95     96                                  failure diagnosis
# 96     97                               Forward engineerings
# 97     98                                       User context
# 98     99                     Strength of Building Materials
# 99    100  the uses of the strategy pinpoint promising in...

# %% [markdown]
# # Authors
# ## I don't know how to parse them better!  Each text file seems to look at them differently and no idea what to do

# %%
sqlAUDF = cmd.createAUTHORSTable(df)
# Out:
# Opened Abstracts_DB2.db database successfully
# Author set created
# Records created successfully

# %%
sqlAUDF.head()
# Out:
#    authorID                   authorName
# 0         1           Von Massow  Robert
# 1         2                Smiley  Karen
# 2         3           Westermann  Dennis
# 3         4                 Porres  Ivan
# 4         5  Dos Santos  Rodrigo Pereira

# %%
print len(sqlAUDF.authorName.drop_duplicates())  #<<--- double check!  will keep one 'empty ' ' becuase of set)
len(sqlAUDF)
# Out:
# 1817
# 1817

# %% [markdown]
# # Affiliation Table
# ## simple no extra parsing do to differences between entries

# %%
affilDF= cmd.createAFFILIATIONTable(df)
# Out:
# Opened Abstracts_DB2.db database successfully
# Created DataFrame
# Records created successfully

# %%
affilDF
# Out:
#      affilID                                        affiliation
# 0          1                   DISP, Univ  of Rome, Rome, Italy
# 1          2                        LSTS   ENIT, Tunis, Tunisia
# 2          3  INRIA, Univ  des Sci  et Technol  de Lille, Vi...
# 3          4  Sch  of Comput  Sci , Univ  of Adelaide, Adela...
# 4          5    Software Group, IBM, Raleigh, NC, United States
# 5          6         Comput  Syst  Dept , UCLM, Albacete, Spain
# 6          7  Dept  of Comput  Sci , Univ  of Aarhus, Arhus,...
# 7          8  Dipt  Estadi   stica, Comput  Univ  de La Lagu...
# 8          9  Comput  Sci  Dept , Pontifical Catholic Univ ,...
# 9         10  Comput  Languages   Syst  II Dept , Rey Juan C...
# 10        11  Div  de Sist  e Ing  Electron   DSIE , Univ  P...
# 11        12  Dept  of Comput  Sci , Univ  of Leicester, Lei...
# 12        13  Dept  of Autom  Control   Syst  Eng , Univ  of...
# 13        14  Dept  of Inf  Syst    Comput , Polytech  Univ ...
# 14        15  Dept  of Inf  Syst    Comput , Tech  Univ  of ...
# 15        16  Dept  for Appl  Telematics   e Bus , Univ  of ...
# 16        17  Sch  of Comput  Sci , Carnegie Mellon Univ , P...
# 17        18  Depto  de Inf , Univ  de Valladolid, Valladoli...
# 18        19  Dept  of Math    Comput  Sci , Univ  of Gronin...
# 19        20  Dept  of Comput  Sci , Univ  of Malaga, Malaga...
# 20        21                                               None
# 21        22  Department of Computer Science, VU University ...
# 22        23  Warsaw University of Technology, Institute of ...
# 23        24  Division of Electronics Engineering and System...
# 24        25  Department of Computer Science, Universidad Re...
# 25        26  Alma Mater Studiorum, Universit    di Bologna,...
# 26        27  Department of Industrial Electronics, Universi...
# 27        28  Dublin City University, School of Computing, D...
# 28        29  Dpto  Lenguajes y Ciencias de la Computaci   n...
# 29        30  Dpto  Estad   stica, I O  y Computaci   n Univ...
# ..       ...                                                ...
# 734      735  Deep SE Group, Dipartimento di Elettronica Inf...
# 735      736  RWTH Aachen University, Research Group Softwar...
# 736      737  Johannes Kepler University Linz, Linz, Austria...
# 737      738  Amrita Vishwa Vidyapeetham, India  2  Universi...
# 738      739  Christian Doppler Laboratory, MEVSS, Johannes ...
# 739      740                  University of Lugano, Switzerland
# 740      741  Department of Computer Science, Federal Univer...
# 741      742  VU University Amsterdam, Netherlands  2  Vienn...
# 742      743  University of Canterbury, Christchurch, New Ze...
# 743      744  Department of Information Engineering, Compute...
# 744      745  Lero   the Irish Software Engineering Research...
# 745      746  University of Groningen, Netherlands  2  ABB C...
# 746      747  Charles University in Prague, Faculty of Mathe...
# 747      748  Department of Information and Computing Scienc...
# 748      749  Department of Computer Science, Linnaeus Unive...
# 749      750  Industrial Software Systems, ABB Corporate Res...
# 750      751  ABB Corporate Research, M   lardalen Universit...
# 751      752  Aalto University, School of Science, Finland  ...
# 752      753  Clausthal University of Technology, Department...
# 753      754  Alten AB, Stockholm, Sweden  2  M   lardalen U...
# 754      755  IT University of Copenhagen, Denmark  2  Unive...
# 755      756  Department of Informatics, Clausthal Universit...
# 756      757  Siemens AG Osterreich, Corporate Technology Vi...
# 757      758  Information Systems Architecture Research Grou...
# 758      759  SWAT Lab , DGIGL, Polytechnique Montr   al, Qu...
# 759      760  Federal University of Bahia, Av  Adhemar de Ba...
# 760      761  University of Groningen, Nijenborgh 9, 9747 AG...
# 761      762  Department of Informatics, Universidad Tecnica...
# 762      763  Dept  of Computer Systems, University of S   o...
# 763      764  ABB Corporate Research Germany, Industrial Sof...
#
# [764 rows x 2 columns]

# %% [markdown]
# # PAPER TABLE
# ## should this actually be made by first doing a join or something with the pub table?

# %%
paperDF= cmd.createPAPERTable(df)
# Out:
# Opened Abstracts_DB2.db database successfully
# table dropped
# Created PAPER table
# Created DataFrame
# Records created successfully

# %%
paperDF
# Out:
#       paperID                                           abstract  \
# 0           1  A Software Product Line  SPL  is a family of r...
# 1           2  A Software Product Line  SPL  is a portfolio o...
# 2           3  A Software Product Line  SPL  is a portfolio o...
# 3           4  A Software Product Line  SPL  is a portfolio o...
# 4           5  A central aspect of architecting is architectu...
# 5           6  A central aspect of architecting is architectu...
# 6           7  A central tenet of software architecture desig...
# 7           8  A common approach to defining architectural vi...
# 8           9  A common approach to software architecture doc...
# 9          10  A common approach to software architecture doc...
# 10         11  A common practice in software architecture des...
# 11         12  A common practice in software architecture des...
# 12         13  A crucial aspect of the software architect   s...
# 13         14  A distributed software system uses a complex s...
# 14         15  A domain specific language  DSL  is designed f...
# 15         16  A growing number of mobile users prefer to acc...
# 16         17  A key aspect in creating autonomous dynamic so...
# 17         18  A key aspect of architecture centric developme...
# 18         19  A key aspect of architecture centric developme...
# 19         20  A key aspect of architecture centric developme...
# 20         21  A key challenge of Web Service  WS  compositio...
# 21         22  A key objective for ubiquitous environments is...
# 22         23  A large IT company is creating a generic archi...
# 23         24  A large IT company is creating a generic archi...
# 24         25  A metamodel based approach is proposed to filt...
# 25         26  A new breed of Web application, dubbed AJAX, i...
# 26         27  A previous study, run by some of the authors i...
# 27         28  A recent survey on software reference architec...
# 28         29  A reference architecture describes core elemen...
# 29         30  A rigorous paradigm coordinating components is...
# ...       ...                                                ...
# 996       997  When constructing software systems, software a...
# 997       998  When designing information systems, architects...
# 998       999  When developing a software system, its archite...
# 999      1000  When developing a software system, its archite...
# 1000     1001  When developing a software system, its archite...
# 1001     1002  When developing and deploying applications in ...
# 1002     1003  When engineering complex and distributed softw...
# 1003     1004  When increasing the complexity of software sys...
# 1004     1005  When increasing the complexity of software sys...
# 1005     1006  When modeling recurring architectural decision...
# 1006     1007  When modeling recurring architectural decision...
# 1007     1008  When organizations cooperate closely, for exam...
# 1008     1009  When software projects evolve their actual imp...
# 1009     1010  When using Software Architecture documents  AD...
# 1010     1011  When using Software Architecture documents  AD...
# 1011     1012  While the performance analysis of a software a...
# 1012     1013  While the performance analysis of a software a...
# 1013     1014  While the use of components grows in software ...
# 1014     1015  While the use of components grows in software ...
# 1015     1016  While the use of components grows in software ...
# 1016     1017  While typical solutions focus on fault toleran...
# 1017     1018  Wide availability of multicore CPUs makes conc...
# 1018     1019  With current trends towards moving variability...
# 1019     1020  With software services becoming a strategic ca...
# 1020     1021  With the evolution of distributed systems in s...
# 1021     1022  With the spread of the Internet and software e...
# 1022     1023  With the widespread adoption of cloud computin...
# 1023     1024  Within the business software domain it is cruc...
# 1024     1025  Within the business software domain it is cruc...
# 1025     1026  Without rigorous software development and main...
#
#                                                   title  \
# 0     On the need of safe software product line arch...
# 1     Feature model to product architectures  Applyi...
# 2     Feature model to product architectures  Applyi...
# 3     Feature model to product architectures  Applyi...
# 4     On the composition and reuse of viewpoints acr...
# 5     On the composition and reuse of viewpoints acr...
# 6     Exploring quality attributes using architectur...
# 7     A model driven approach to extract views from ...
# 8     Ontology based software architecture documenta...
# 9     Ontology based software architecture documenta...
# 10    Software language engineering of architectural...
# 11    Defining architectural viewpoints for quality ...
# 12                     Using architectural perspectives
# 13    Performance analysis of distributed software s...
# 14    A domain specific language for XML security st...
# 15    An integrated lightweight software architectur...
# 16                 Explicit models for dynamic software
# 17    Assisting the synchronization of UCM based arc...
# 18    Assisting the synchronization of UCM based arc...
# 19    Assisting the synchronization of UCM based arc...
# 20    Verifying composite service transactional beha...
# 21    Mediating connector patterns for components in...
# 22    The influence of CMMI on establishing an archi...
# 23    The influence of CMMI on establishing an archi...
# 24    TopDocs  Using software architecture knowledge...
# 25                      An architectural style for AJAX
# 26    Architecture description leveraging model driv...
# 27    Towards an Improved Stakeholder Management for...
# 28    Empirically grounded reference architectures  ...
# 29    An ADL Approach to Specifying and Analyzing Ce...
# ...                                                 ...
# 996   Combining pattern languages and reusable archi...
# 997   Rationale, decisions and alternatives traceabi...
# 998   A model to represent architectural design rati...
# 999   A model to represent architectural design rati...
# 1000  A model to represent architectural design rati...
# 1001  Architectural tactics support in cloud computi...
# 1002  A practical architecture centric analysis process
# 1003  AspectLEDA  Extending an ADL with aspectual co...
# 1004  AspectLEDA  Extending an ADL with aspectual co...
# 1005  Architectural decision identification in archi...
# 1006  Architectural decision identification in archi...
# 1007  Architectural reuse in software systems in hou...
# 1008  Automated architecture consistency checking fo...
# 1009  A study of architectural information foraging ...
# 1010  A study of architectural information foraging ...
# 1011  Enabling performance antipatterns to arise fro...
# 1012  Enabling performance antipatterns to arise fro...
# 1013  Automated architectural component classificati...
# 1014  Automated architectural component classificati...
# 1015  Automated architectural component classificati...
# 1016                Architecting fault tolerant systems
# 1017  Experiences with modeling memory contention fo...
# 1018  A NUI based multiple perspective variability m...
# 1019  Dynamic adaptive service architecture   Toward...
# 1020  Towards a multi scale modeling for architectur...
# 1021  Towards a formal model for reconfigurable soft...
# 1022  A framework for architecture driven migration ...
# 1023  The role of variability patterns in multi tena...
# 1024  The role of variability patterns in multi tena...
# 1025  A case study in incremental architecture based...
#
#                                                   terms  \
# 0     ['Software design', 'Structural properties', '...
# 1     ['Architecture', 'Computer software', 'Network...
# 2     ['Architecture', 'Computer software', 'Network...
# 3     ['Architecture', 'Computer software', 'Network...
# 4     ['Architecture description languages', 'Archit...
# 5     ['Architecture description languages', 'Archit...
# 6     ['software architecture', 'software prototypin...
# 7     ['high level languages', 'software architectur...
# 8     ['Semantics', 'Architectural knowledge', 'Indu...
# 9     ['Semantics', 'Architectural knowledge', 'Indu...
# 10    ['Design', 'Software design', 'Architectural V...
# 11    ['Open systems', 'Software design', 'Architect...
# 12    ['Engineers', 'Industrial economics', 'Marketi...
# 13    ['Internet', 'queueing theory', 'software perf...
# 14    ['Problem oriented languages', 'Software archi...
# 15    ['Architecture', 'Data compression', 'Global s...
# 16    ['Autonomous agents', 'Computer aided design',...
# 17    ['Architecture', 'Computer software', 'Archite...
# 18    ['Architecture', 'Computer software', 'Archite...
# 19    ['Architecture', 'Computer software', 'Archite...
# 20    ['Quality of service', 'Software architecture'...
# 21    ['Interoperability', 'Architectural pattern', ...
# 22    ['Computer software selection and evaluation',...
# 23    ['Capability Maturity Model', 'DP management',...
# 24    ['Knowledge based systems', 'Knowledge managem...
# 25    ['client-server systems', 'Internet', 'Java', ...
# 26    ['Embedded systems', 'Software architecture', ...
# 27    ['software architecture', 'software management...
# 28    ['Design', 'Interoperability', 'Reusability', ...
# 29    ['program verification', 'software architectur...
# ...                                                 ...
# 996   ['Computer software', 'Computer software reusa...
# 997   ['Design', 'Information systems', 'Maintainabi...
# 998   ['Architectural design', 'Computer software', ...
# 999   ['Architectural design', 'Computer software', ...
# 1000  ['Architectural design', 'Computer software', ...
# 1001  ['Cloud computing', 'Commerce', 'Architectural...
# 1002  ['formal specification', 'formal verification'...
# 1003  ['Architectural design', 'Computer software se...
# 1004  ['Architectural design', 'Computer software se...
# 1005  ['Information services', 'Knowledge management...
# 1006  ['Information services', 'Knowledge management...
# 1007  ['business data processing', 'formal specifica...
# 1008  ['Computer software maintenance', 'Computer so...
# 1009  ['Natural resources exploration', 'Design deci...
# 1010  ['Natural resources exploration', 'Design deci...
# 1011  ['Probability distributions', 'AEmilia ADL', '...
# 1012  ['Probability distributions', 'AEmilia ADL', '...
# 1013  ['Architecture', 'Computer software', 'Archite...
# 1014  ['Architecture', 'Computer software', 'Archite...
# 1015  ['Architecture', 'Computer software', 'Archite...
# 1016  ['exception handling', 'software architecture'...
# 1017  ['Concurrency control', 'Locks (fasteners)', '...
# 1018  ['Production engineering', 'Visualization', 'B...
# 1019  ['Adaptation techniques', 'Adaptive architectu...
# 1020  ['Artificial intelligence', 'Computer science'...
# 1021  ['Architecture', 'Chlorine compounds', 'Digita...
# 1022  ['Cloud computing', 'Reengineering', 'Reusabil...
# 1023  ['Software architecture', 'Multi-tenancy', 'On...
# 1024  ['Software architecture', 'Multi-tenancy', 'On...
# 1025  ['Computer programming languages', 'Computer s...
#
#                                                 authors  \
# 0     ['Lopez Herrejon, Roberto E', '', '', ' Egyed,...
# 1     ['Perovich, Daniel', '', '', 'Rossel, Pedro O'...
# 2     ['Perovich, Daniel', '', '', 'Rossel, Pedro O'...
# 3     ['Perovich, Daniel', '', '', 'Rossel, Pedro O'...
# 4     ['Hilliard, Rich', '', '', 'Malavolta, Ivano',...
# 5     ['Hilliard, Rich', '', '', 'Malavolta, Ivano',...
# 6     ['Bardram, J E', '', '', ' Christensen, H B', ...
# 7            ['Oliveira, C', '', '', ' Wermelinger, M']
# 8     ['De Graaf, Klaas Andries', '', '', 'Tang, Ant...
# 9     ['De Graaf, Klaas Andries', '', '', 'Tang, Ant...
# 10     ['Demirli, Elif', '', '', 'Tekinerdogan, Bedir']
# 11    ['Tekinerdogan, Bedir', '', '', 'S', ' zer, Ha...
# 12            ['Woods, Eoin', '', '', 'Rozanski, Nick']
# 13    ['Source', '', '', ' Working IEEE IFIP Confere...
# 14    ['Schefer Wenzl, Sigrid', '', '', 'Feiertag, K...
# 15    ['Dagtas, Serhan', ' ,', '', ' Natchetoi, Yuri...
# 16    ['Bosloper, Ivor', '', '', 'Siljee, Johanneke'...
# 17    ['Diaz Pace, J', 'Andres', '', '', 'Carlino, J...
# 18    ['Diaz Pace, J', 'Andres', '', '', 'Carlino, J...
# 19    ['Diaz Pace, J', 'Andres', '', '', 'Carlino, J...
# 20    ['Hamel, Lazhar', '', '', 'Graiet, Mohamed', '...
# 21    ['Spalazzese, Romina', '', '', 'Inverardi, Pao...
# 22    ['Poort, Eltjo R', '', '', ' Postema, Herman',...
# 23    ['Poort, E R', '', '', ' Postema, H', '', '', ...
# 24    ['Eloranta, Veli Pekka', '', '', 'Hylli, Otto'...
# 25     ['Mesbah, A', '', '', ' van Deursen, A', '', '']
# 26    ['Baroni, Alessandro', '', '', 'Muccini, Henry...
# 27               ['Angelov, S', '', '', ' Hilliard, R']
# 28     ['Galster, Matthias', '', '', 'Avgeriou, Paris']
# 29    ['Guoxin Su', '', '', 'Mingsheng Ying', '', ''...
# ...                                                 ...
# 996   ['Zimmermann, Olaf', '', '', 'Zdun, Uwe', '', ...
# 997    ['Gilson, Fabian', '', '', 'Englebert, Vincent']
# 998   ['Carignano, Mar', ' a Celeste', '', '', 'Gonn...
# 999   ['Carignano, Mar', ' a Celeste', '', '', 'Gonn...
# 1000  ['Carignano, Mar', ' a Celeste', '', '', 'Gonn...
# 1001  ['Chavarriaga, Jaime', '', '', 'Noguera, Carlo...
# 1002  ['Bucchiarone, A', '', '', ' Muccini, H', ' Pe...
# 1003  ['Navasa, Amparo', '', '', 'P', ' rez, Miguel ...
# 1004  ['Navasa, Amparo', '', '', 'P', ' rez, Miguel ...
# 1005                               ['Zimmermann, Olaf']
# 1006                               ['Zimmermann, Olaf']
# 1007  ['Land, R', '', '', ' Crnkovic, I', '', '', ' ...
# 1008   ['Biehl, Matthias', ' ,', '', ' L', ' we, Welf']
# 1009  ['Su, Moon Ting', '', '', 'Tempero, Ewan', '',...
# 1010  ['Su, Moon Ting', '', '', 'Tempero, Ewan', '',...
# 1011  ['Cortellessa, Vittorio', '', '', 'De Sanctis,...
# 1012  ['Cortellessa, Vittorio', '', '', 'De Sanctis,...
# 1013  ['Aboud, Nour Alhouda', '', '', 'Ar', ' valo, ...
# 1014  ['Aboud, Nour Alhouda', '', '', 'Ar', ' valo, ...
# 1015  ['Aboud, Nour Alhouda', '', '', 'Ar', ' valo, ...
# 1016  ['Muccini, H', ' Pelliccione, P', ' Romanovsky...
# 1017  ['De Gooijer, Thijmen', '', '', 'Harper, K', '...
# 1018                           ['Bashroush, R', '', '']
# 1019                                    ['Pahl, Claus']
# 1020  ['Gassara, Amal', '', '', 'Bouassida Rodriguez...
# 1021  ['Chang, Zhiming', '', '', 'Mao, Xinjun', '', ...
# 1022  ['Ahmad, Aakash', '', '', 'Babar, Muhammad Ali...
# 1023     ['Kabbedijk, J', '', '', ' Jansen, S', '', '']
# 1024     ['Kabbedijk, J', '', '', ' Jansen, S', '', '']
# 1025   ['Abi Antoun, Marwan', '', '', 'Coelho, Wesley']
#
#                                             affiliation  pubYear confName
# 0     Institute for Systems Engineering and Automati...     2010     ECSA
# 1     CS Department, Universidad de Chile, Santiago,...     2009     ECSA
# 2     CS Department, Universidad de Chile, Santiago,...     2009    WICSA
# 3     CS Department, Universidad de Chile, Santiago,...     2011    WICSA
# 4     Dipartimento di Informatica, Universit    dell...     2012     ECSA
# 5     Dipartimento di Informatica, Universit    dell...     2012    WICSA
# 6     Dept  of Comput  Sci , Aarhus Univ , Aarhus, D...     2005     QoSA
# 7     Dept  of Comput  Sci , Univ  of Leicester, Lei...     2007    WICSA
# 8     VU University, Netherlands  2  Swinburne Unive...     2012     ECSA
# 9     VU University, Netherlands  2  Swinburne Unive...     2012    WICSA
# 10    Department of Computer Engineering, Bilkent Un...     2011     ECSA
# 11    Bilkent University, Department of Computer Eng...     2011     ECSA
# 12                                             Artechra     2005    WICSA
# 13                                                 None     2007    WICSA
# 14    Competence Center for IT Security, University ...     2014     ECSA
# 15    SAP Labs , Canada  2  University of Arkansas, ...     2008    WICSA
# 16    Department of Mathematics and Computer Science...     2005    WICSA
# 17    Software Engineering Institute, Carnegie Mello...     2009     ECSA
# 18    Software Engineering Institute, Carnegie Mello...     2009    WICSA
# 19    Software Engineering Institute, Carnegie Mello...     2011    WICSA
# 20    MIRACL, ISIMS, Tunisia  2  Computer Science De...     2011     ECSA
# 21    Universit    Degli Studi dell   Aquila, via Ve...     2010     ECSA
# 22    LogicaCMG, P O  Box 159, Amstelveen 1180 AD, N...     2007     QoSA
# 23    LogicaCMG, Amstelveen, Netherlands  2  LogicaC...     2008     QoSA
# 24    Department of Software Systems, Tampere Univer...     2012    WICSA
# 25    Software Evolution Res  Lab , Delft Univ  of T...     2007    WICSA
# 26    Department of Information Engineering, Compute...     2014    WICSA
# 27    Software Eng , Fontys Univ  of Appl  Sci , Ein...     2014     ECSA
# 28                 University of Groningen, Netherlands     2011     QoSA
# 29    Centre for Quantum Comput    Intell  Syst , Un...     2010     ECSA
# ...                                                 ...      ...      ...
# 996   IBM Research GmbH, Zurich Research Laboratory,...     2008    WICSA
# 997   PReCISE Research Center, Faculty of Computer S...     2011     ECSA
# 998   INGAR CIDISI, UTN, Santa Fe, Argentina  2  ING...     2009     ECSA
# 999   INGAR CIDISI, UTN, Santa Fe, Argentina  2  ING...     2009    WICSA
# 1000  INGAR CIDISI, UTN, Santa Fe, Argentina  2  ING...     2011    WICSA
# 1001  Universidad de Los Andes, Vrije Universiteit B...     2014     QoSA
# 1002    Ist  di Sci  e Tecnol  dell   Inf , Pisa, Italy     2006     QoSA
# 1003  Quercus Software Engineering Group, Department...     2007     ECSA
# 1004  Quercus Software Engineering Group, Department...     2008     ECSA
# 1005  ABB Corporate Research, Industrial Software Sy...     2012     ECSA
# 1006  ABB Corporate Research, Industrial Software Sy...     2012    WICSA
# 1007  Dept  of Comput  Sci    Electron , Malardalen ...     2005     QoSA
# 1008  Software Technology Group, V   xj    Universit...     2009     QoSA
# 1009  Department of Computer Science, University of ...     2012     ECSA
# 1010  Department of Computer Science, University of ...     2012    WICSA
# 1011      Universit    degli Studi dell   Aquila, Italy     2012     ECSA
# 1012      Universit    degli Studi dell   Aquila, Italy     2012    WICSA
# 1013  LIUPPA, Univ  de Pau et des Pays de l   Adour,...     2009     ECSA
# 1014  LIUPPA, Univ  de Pau et des Pays de l   Adour,...     2009    WICSA
# 1015  LIUPPA, Univ  de Pau et des Pays de l   Adour,...     2011    WICSA
# 1016                                               None     2007    WICSA
# 1017  ABB Corporate Research, V   steras, Sweden  2 ...     2014     QoSA
# 1018  School of Computing, IT and Engineering, Unive...     2010     ECSA
# 1019  School of Computing, Dublin City University, D...     2010     ECSA
# 1020  ReDCAD, University of Sfax, B P  1173, 3038 Sf...     2013     ECSA
# 1021  Dept  of Computer Science, National University...     2008    WICSA
# 1022  IT University of Copenhagen, Denmark  2  Unive...     2014    WICSA
# 1023  Information and Computing Sciences, Utrecht Un...     2012     ECSA
# 1024  Information and Computing Sciences, Utrecht Un...     2012    WICSA
# 1025  Institute for Software Research Intl  ISRI , C...     2005    WICSA
#
# [1026 rows x 8 columns]

# %% [markdown]
# # to do:
# -  many to many paper : keyword
# -  many to many paper : author
# - many to many paper : affiliation
